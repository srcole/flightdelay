# %% [markdown]
# # Explore flight delay data wrt month

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
sns.set_style('white')

# %% [markdown]
# # Load data

# %%
# Import custom code
from flightdelay.fld import io as flio
airlines_df, airports_df, flights_df = flio.load_data()

# %%
# Filter data to keys of interest
keys = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER', 'TAIL_NUMBER', 'ORIGIN_AIRPORT',
       'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
       'DEPARTURE_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME',
       'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN',
       'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY']
flights_df = flights_df[keys]

# %%
all_airports, airport_inverse, airport_count = np.unique(flights_df['ORIGIN_AIRPORT'],return_counts=True,return_inverse=True)

# Determine number of flights for the origin airport
Nflights_orig = np.zeros(len(airport_inverse))
for i in range(len(all_airports)):
    Nflights_orig[np.where(airport_inverse==i)] = airport_count[i]
    
flights_df = flights_df.loc[flights_df.index[Nflights_orig>=7300]]

# %%
# Remove cancelled flights
flights_df = flights_df.dropna()
flights_df.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1            4      AS             98      N407AS            ANC
# 1      1    1            4      AA           2336      N3KUAA            LAX
# 2      1    1            4      US            840      N171US            SFO
# 3      1    1            4      AA            258      N3HYAA            LAX
# 4      1    1            4      AS            135      N527AS            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME      ...        \
# 0                 SEA                    5          2354.0      ...
# 1                 PBI                   10             2.0      ...
# 2                 CLT                   20            18.0      ...
# 3                 MIA                   20            15.0      ...
# 4                 ANC                   25            24.0      ...
#
#    WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  \
# 0        15.0           205.0         194.0     169.0      1448      404.0
# 1        14.0           280.0         279.0     263.0      2330      737.0
# 2        34.0           286.0         293.0     266.0      2296      800.0
# 3        30.0           285.0         281.0     258.0      2342      748.0
# 4        35.0           235.0         215.0     199.0      1448      254.0
#
#    TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY
# 0      4.0                430         408.0          -22.0
# 1      4.0                750         741.0           -9.0
# 2     11.0                806         811.0            5.0
# 3      8.0                805         756.0           -9.0
# 4      5.0                320         259.0          -21.0
#
# [5 rows x 22 columns]

# %%
# Separate data by airport
all_airports, airport_inverse, airport_count = np.unique(flights_df['ORIGIN_AIRPORT'],return_counts=True,return_inverse=True)

airport_dfs = {}
for k in all_airports:
    airport_dfs[k] = flights_df[flights_df['ORIGIN_AIRPORT']==k]

# %% [markdown]
# # General exploration function
#
# Input:
#     Analysis type
#     Mean_by_group
#     plot_quantiles
#     Output:

# %%
airport_dfs['SAN']
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 477          1    1            4      DL            978      N693DL
# 500          1    1            4      OO           5608      N930SW
# 517          1    1            4      WN            823      N7707C
# 518          1    1            4      WN            603      N461WN
# 520          1    1            4      UA           1192      N69804
# 521          1    1            4      UA           1568      N24212
# 525          1    1            4      AA           1390      N496AA
# 582          1    1            4      DL           1592      N723TW
# 595          1    1            4      US            567      N524UW
# 601          1    1            4      AS            499      N551AS
# 602          1    1            4      AS            573      N467AS
# 626          1    1            4      OO           2604      N693BR
# 655          1    1            4      DL           1864      N360NW
# 733          1    1            4      DL            246      N391DA
# 792          1    1            4      UA           1510      N37255
# 903          1    1            4      AS            847      N558AS
# 967          1    1            4      OO           3479      N218AG
# 1002         1    1            4      AA             70      N5BTAA
# 1018         1    1            4      DL           2109      N550NW
# 1044         1    1            4      WN            435      N714CB
# 1084         1    1            4      WN            205      N624SW
# 1412         1    1            4      UA            546      N514UA
# 1516         1    1            4      AA             94      N3ANAA
# 1562         1    1            4      UA            662      N475UA
# 1581         1    1            4      WN            336      N490WN
# 1616         1    1            4      AS            493      N794AS
# 1678         1    1            4      NK            858      N515NK
# 1782         1    1            4      WN           2400      N405WN
# 1908         1    1            4      UA            484      N809UA
# 2015         1    1            4      WN            411      N8614M
# ...        ...  ...          ...     ...            ...         ...
# 5816039     12   31            4      WN           5563      N569WN
# 5816289     12   31            4      WN           1459      N640SW
# 5816345     12   31            4      WN           5253      N354SW
# 5816504     12   31            4      VX            963      N853VA
# 5816541     12   31            4      UA            370      N801UA
# 5816569     12   31            4      NK            108      N523NK
# 5816756     12   31            4      AS            233      N433AS
# 5817131     12   31            4      WN           5405      N700GS
# 5817197     12   31            4      WN           3066      N340LV
# 5817214     12   31            4      AS            579      N791AS
# 5817346     12   31            4      UA            522      N490UA
# 5817363     12   31            4      WN           5382      N748SW
# 5817406     12   31            4      WN           2511      N7823A
# 5817450     12   31            4      WN           5281      N648SW
# 5817513     12   31            4      WN           5292      N245WN
# 5817582     12   31            4      OO           6342      N118SY
# 5817695     12   31            4      WN           1642      N445WN
# 5817882     12   31            4      AA            464      N191UW
# 5817929     12   31            4      AS            485      N713AS
# 5818092     12   31            4      UA            384      N476UA
# 5818398     12   31            4      WN           1971      N294WN
# 5818405     12   31            4      AS            497      N483AS
# 5818445     12   31            4      NK           1104      N505NK
# 5818544     12   31            4      AS            717      N585AS
# 5818569     12   31            4      B6             90      N579JB
# 5818812     12   31            4      B6             20      N608JB
# 5818816     12   31            4      UA           1916      N69829
# 5818883     12   31            4      DL           1792      N1402A
# 5818899     12   31            4      UA            240      N30401
# 5818918     12   31            4      DL           1366      N341NW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 477                SAN                 SLC                  615
# 500                SAN                 LAX                  615
# 517                SAN                 BWI                  620
# 518                SAN                 MDW                  620
# 520                SAN                 DEN                  620
# 521                SAN                 EWR                  620
# 525                SAN                 DFW                  620
# 582                SAN                 ATL                  629
# 595                SAN                 PHX                  630
# 601                SAN                 SEA                  630
# 602                SAN                 PDX                  630
# 626                SAN                 LAX                  630
# 655                SAN                 MSP                  635
# 733                SAN                 JFK                  645
# 792                SAN                 IAH                  653
# 903                SAN                 OGG                  700
# 967                SAN                 SLC                  700
# 1002               SAN                 DFW                  705
# 1018               SAN                 DTW                  705
# 1044               SAN                 DAL                  710
# 1084               SAN                 SJC                  715
# 1412               SAN                 IAD                  745
# 1516               SAN                 JFK                  755
# 1562               SAN                 SFO                  800
# 1581               SAN                 SEA                  800
# 1616               SAN                 SEA                  800
# 1678               SAN                 IAH                  800
# 1782               SAN                 HOU                  810
# 1908               SAN                 DEN                  820
# 2015               SAN                 AUS                  830
# ...                ...                 ...                  ...
# 5816039            SAN                 SJC                 1645
# 5816289            SAN                 PHX                 1705
# 5816345            SAN                 OAK                 1710
# 5816504            SAN                 SFO                 1725
# 5816541            SAN                 SFO                 1727
# 5816569            SAN                 DFW                 1730
# 5816756            SAN                 SEA                 1740
# 5817131            SAN                 SAT                 1810
# 5817197            SAN                 SFO                 1815
# 5817214            SAN                 PDX                 1815
# 5817346            SAN                 SFO                 1830
# 5817363            SAN                 LAS                 1830
# 5817406            SAN                 SEA                 1835
# 5817450            SAN                 TUS                 1840
# 5817513            SAN                 PDX                 1845
# 5817582            SAN                 LAX                 1853
# 5817695            SAN                 ABQ                 1905
# 5817882            SAN                 PHX                 1925
# 5817929            SAN                 SEA                 1930
# 5818092            SAN                 SFO                 1955
# 5818398            SAN                 SFO                 2030
# 5818405            SAN                 SEA                 2030
# 5818445            SAN                 DEN                 2038
# 5818544            SAN                 SLC                 2055
# 5818569            SAN                 JFK                 2100
# 5818812            SAN                 BOS                 2200
# 5818816            SAN                 EWR                 2202
# 5818883            SAN                 ATL                 2230
# 5818899            SAN                 ORD                 2235
# 5818918            SAN                 DTW                 2245
#
#          DEPARTURE_TIME      ...        WHEELS_OFF  SCHEDULED_TIME  \
# 477               611.0      ...             631.0           121.0
# 500               614.0      ...             630.0            52.0
# 517               620.0      ...             638.0           295.0
# 518               617.0      ...             634.0           250.0
# 520               618.0      ...             636.0           145.0
# 521               615.0      ...             633.0           320.0
# 525               612.0      ...             639.0           185.0
# 582               628.0      ...             644.0           241.0
# 595               623.0      ...             640.0            83.0
# 601               627.0      ...             643.0           180.0
# 602               624.0      ...             641.0           160.0
# 626               620.0      ...             637.0            55.0
# 655               632.0      ...             649.0           224.0
# 733               642.0      ...             657.0           314.0
# 792               655.0      ...             709.0           188.0
# 903               656.0      ...             715.0           357.0
# 967               721.0      ...             738.0           110.0
# 1002              659.0      ...             721.0           180.0
# 1018              703.0      ...             716.0           259.0
# 1044              709.0      ...             723.0           170.0
# 1084              709.0      ...             717.0            80.0
# 1412              739.0      ...             751.0           282.0
# 1516              810.0      ...             823.0           320.0
# 1562              758.0      ...             813.0           100.0
# 1581              755.0      ...             810.0           175.0
# 1616              752.0      ...             806.0           174.0
# 1678              752.0      ...             802.0           178.0
# 1782              807.0      ...             816.0           175.0
# 1908              811.0      ...             825.0           146.0
# 2015              825.0      ...             837.0           165.0
# 5817363               1940        1944.0            4.0
# 5817406               2135        2150.0           15.0
# 5817450               2050        2106.0           16.0
# 5817513               2120        2153.0           33.0
# 5817582               1946        1938.0           -8.0
# 5817695               2145        2142.0           -3.0
# 5817882               2141        2143.0            2.0
# 5817929               2225        2216.0           -9.0
# 5818092               2136        2119.0          -17.0
# 5818398               2200        2206.0            6.0
# 5818405               2329        2303.0          -26.0
# 5818445               2355        2357.0            2.0
# 5818544               2350        2336.0          -14.0
# 5818569                501         428.0          -33.0
# 5818812                609         533.0          -36.0
# 5818816                600         537.0          -23.0
# 5818883                524         511.0          -13.0
# 5818899                443         405.0          -38.0
# 5818918                604         530.0          -34.0
#
# [75454 rows x 22 columns]

# %%
# Plot mean flight delay for all months for multiple airports
import util
analysis_fn = util.relation_mean
aps = ['SAN','LAX','SEA','LGA','ORD','MIA']
y_by_x_mean = {}
for ap in aps:
    y_by_x_mean[ap] = util.relation_explorer(airport_dfs[ap], 'DEPARTURE_DELAY', 'MONTH',analysis_fn = analysis_fn,make_plot=False)

# %%
def getcmaprgb(N, cmap):
	"""Get the RGB values of N colors across a colormap"""
	return cmap(np.linspace(0,255,N).astype(int))

# %%
from matplotlib import cm
colors = getcmaprgb(len(aps),cm.jet)

plt.figure(figsize=(10,5))    
for i, ap in enumerate(aps):
    plt.plot(np.arange(1,13),y_by_x_mean[ap],'.-',color=colors[i],label=ap)
plt.xlabel('Month',size=20)
plt.ylabel('Average delay (min)', size=20)
plt.title('Flight delay by month',size=20)
plt.xlim((.5,14.5))
plt.yticks(size=15)
plt.xticks(np.arange(1,13),['J','F','M','A','M','J','J','A','S','O','N','D'],size=15)
plt.legend(loc='best',fontsize=12)

# %% [markdown]
# # Find mean and count of whole data set by month

# %%
gbm = flights_df[['MONTH','DEPARTURE_DELAY']].groupby('MONTH')
gbm_mean = gbm.agg(['mean','count'])
gbm_mean

delay_means = gbm_mean['DEPARTURE_DELAY']['mean'].values
flight_counts = gbm_mean['DEPARTURE_DELAY']['count'].values
plt.figure(figsize=(3,3))
plt.plot(flight_counts,delay_means,'k.')
print(sp.stats.pearsonr(flight_counts,delay_means))
# Out:
# (0.068606114458678188, 0.83221972726180482)

# %%
g = gbm_mean['DEPARTURE_DELAY']['count'].values / np.sum(gbm_mean['DEPARTURE_DELAY']['count'])
plt.plot(np.arange(1,13),g)
print(g)
# Out:
# [ 0.07976092  0.07117805  0.08591138  0.08396606  0.08590642  0.08617159
#   0.08977572  0.08799747  0.08093054  0.08472975  0.08122371  0.0824484 ]

# %%
gbm = airport_dfs[ap][['MONTH','DEPARTURE_DELAY']].groupby('MONTH')
gbm_mean = gbm.agg(['mean','count'])
gbm_mean

delay_means = gbm_mean['DEPARTURE_DELAY']['mean'].values
flight_counts = gbm_mean['DEPARTURE_DELAY']['count'].values
plt.figure(figsize=(3,3))
plt.plot(flight_counts,delay_means,'k.')
print(sp.stats.pearsonr(flight_counts,delay_means))
# Out:
# (0.42036109840469166, 0.17363493096842694)
